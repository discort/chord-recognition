# %%
import itertools
import os
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, Subset
from torchvision import transforms
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

PROJECT_DIR = os.path.dirname(os.getcwd())
if PROJECT_DIR not in sys.path:
    sys.path.insert(0, PROJECT_DIR)

from chord_recognition.cache import HDF5Cache
from chord_recognition.evaluate import evaluate_dataset, print_ds_compute_average_scores
from chord_recognition.models.deep_harmony import deep_harmony
from chord_recognition.dataset import make_batch_frame_log_spec_dataset, prepare_datasource
from chord_recognition.transformations import Rescale
from chord_recognition.train import Solver, data_processing

torch.manual_seed(2020)
RANDOM_STATE = 42

# %matplotlib inline
plt.rcParams['figure.figsize'] = (14, 5)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Exp. 6
# 1-layer CNN (32 filters)
# 3-layer ResCNN (32 filters) with layernorm, GELU activation
# 3-layer LSTM with 128 hidden dims including layernorm

# %%
window_size = 8192
hop_length = 4410
seq_length = 100
#ds = prepare_datasource(('beatles', 'zweieck', 'queen', 'robbie_williams'))
ds = prepare_datasource(('beatles',))
cache = HDF5Cache(os.path.join(PROJECT_DIR, 'spectrogram_ann_cache.hdf5'))

dataset = make_batch_frame_log_spec_dataset(
    datasource=ds,
    window_size=window_size,
    hop_length=hop_length,
    seq_length=seq_length,
    cache=cache
)

# %%
# Split dataset into train/val
indices = np.arange(len(dataset))
idx_train, idx_val = train_test_split(
    indices, test_size=0.2, random_state=RANDOM_STATE)

# %%
train_data = Subset(dataset, idx_train)

# Calculate TRAIN_MEAN, TRAIN_STD
X_train_temp = np.vstack([xi for xi,_ in train_data])
TRAIN_MEAN = X_train_temp.mean(axis=0).reshape(1, -1)
TRAIN_STD = X_train_temp.std(axis=0).reshape(1, -1)

del X_train_temp

# %%
val_data = Subset(dataset, idx_val)

transform = transforms.Compose([
    Rescale(TRAIN_MEAN, TRAIN_STD),
])

train_data.dataset.transform = transform
val_data.dataset.transform = transform

# %%
batch_size = 128

# Split dataset into train/val datasets
loader_train = DataLoader(
    dataset=train_data,
    batch_size=batch_size,
    shuffle=True,
    pin_memory=True,
    collate_fn=lambda x: data_processing(x),
    num_workers=0)
loader_val = DataLoader(
    dataset=val_data,
    num_workers=0,
    collate_fn=lambda x: data_processing(x),
    batch_size=batch_size)

dataloaders = {
    "train": loader_train,
    "val": loader_val
}

# %%
model = deep_harmony(
    n_feats=105,
    n_rnn_layers=3,
    cnn_kwargs=dict(n_cnn_layers=2, block_depth=2, nonlinearity=nn.ReLU))

if torch.cuda.is_available():
    model.cuda()

learning_rate = 1e-3
epochs=100
weight_decay = 0
optimizer = optim.AdamW(
    model.parameters(),
    lr=learning_rate,
    betas=(0.9, 0.999),
    weight_decay=weight_decay)
scheduler = optim.lr_scheduler.OneCycleLR(
    optimizer=optimizer,
    max_lr=1e-3,
    steps_per_epoch=len(loader_train),
    epochs=epochs,
    anneal_strategy='linear',
)

solver = Solver(
    model=model,
    optimizer=optimizer,
    dataloaders=dataloaders,
    scheduler=scheduler,
    trained_model_name="deep_harmony_exp6_2.pth",
    epochs=epochs)
solver.train()
# Out:
#  WER
# 	training         	 (min:    0.813, max:    7.123, cur:    0.817)
# 	validation       	 (min:    0.810, max:    6.587, cur:    0.810)
#  log loss
# 	training         	 (min:    2.375, max:   53.888, cur:    2.375)
# 	validation       	 (min:    2.937, max:   50.476, cur:    3.011)

# %%
# Evaluate exp model

# %%
audio_processor = dataset.dataset.audio_processor
spec_dataset = dataset.dataset

model = deep_harmony(pretrained=True,
                     model_name="deep_harmony_exp6.pth",
                     n_feats=105,
                     cnn_kwargs=dict(n_cnn_layers=3),
                     num_classes=26,
                     n_rnn_layers=3)

evaluate_dataset(
    dataset=spec_dataset,
    model=model,
    save_ann=True)
# Out:
# Process: <01-A_Hard_Day_s_Night>
# Process: <02-I_Should_Have_Known_Better>
# Process: <03-If_I_Fell>
# Process: <04-I_m_Happy_Just_To_Dance_With_You>
# Process: <05-And_I_Love_Her>
# Process: <06-Tell_Me_Why>
# Process: <07-Can_t_Buy_Me_Love>
# Process: <08-Any_Time_At_All>
# Process: <09-I_ll_Cry_Instead>
# Process: <10-Things_We_Said_Today>
# Process: <11-When_I_Get_Home>
# Process: <12-You_Can_t_Do_That>
# Process: <13-I_ll_Be_Back>
# Process: <01-Come_Together>
# Process: <02-Something>
# Process: <03-Maxwell_s_Silver_Hammer>
# Process: <04-Oh_Darling>
# Process: <05-Octopus_s_Garden>
# Process: <06-I_Want_You_She_s_So_Heavy_>
# Process: <07-Here_Comes_The_Sun>
# Process: <08-Because>
# Process: <09-You_Never_Give_Me_Your_Money>
# Process: <10-Sun_King>
# Process: <11-Mean_Mr_Mustard>
# Process: <12-Polythene_Pam>
# Process: <13-She_Came_In_Through_The_Bathroom_Window>
# Process: <14-Golden_Slumbers>
# Process: <15-Carry_That_Weight>
# Process: <16-The_End>
# Process: <17-Her_Majesty>
# Process: <01-No_Reply>
# Process: <02-I_m_A_Loser>
# Process: <03-Baby_s_In_Black>
# Process: <04-Rock_And_Roll_Music>
# Process: <05-I_ll_Follow_The_Sun>
# Process: <06-Mr_Moonlight>
# Process: <07-Medley_Kansas_City_Hey_Hey>
# Process: <08-Eight_Days_A_Week>
# Process: <09-Words_Of_Love>
# Process: <10-Honey_Don_t>
# Process: <11-Every_Little_Thing>
# Process: <12-I_Don_t_Want_To_Spoil_The_Party>
# Process: <13-What_You_re_Doing>
# Process: <14-Everybody_s_Trying_To_Be_My_Baby>
# Process: <01-Help_>
# Process: <02-The_Night_Before>
# Process: <03-You_ve_Got_To_Hide_Your_Love_Away>
# Process: <04-I_Need_You>
# Process: <05-Another_Girl>
# Process: <06-You_re_Going_To_Lose_That_Girl>
# Process: <07-Ticket_To_Ride>
# Process: <08-Act_Naturally>
# Process: <09-It_s_Only_Love>
# Process: <10-You_Like_Me_Too_Much>
# Process: <11-Tell_Me_What_You_See>
# Process: <12-I_ve_Just_Seen_A_Face>
# Process: <13-Yesterday>
# Process: <14-Dizzy_Miss_Lizzy>
# Process: <01-Two_Of_Us>
# Process: <02-Dig_A_Pony>
# Process: <03-Across_The_Universe>
# Process: <04-I_Me_Mine>
# Process: <05-Dig_It>
# Process: <06-Let_It_Be>
# Process: <07-Maggie_Mae>
# Process: <08-I_ve_Got_A_Feeling>
# Process: <09-One_After_909>
# Process: <10-The_Long_And_Winding_Road>
# Process: <11-For_You_Blue>
# Process: <12-Get_Back>
# Process: <01-Magical_Mystery_Tour>
# Process: <02-The_Fool_On_The_Hill>
# Process: <03-Flying>
# Process: <04-Blue_Jay_Way>
# Process: <05-Your_Mother_Should_Know>
# Process: <06-I_Am_The_Walrus>
# Process: <07-Hello_Goodbye>
# Process: <08-Strawberry_Fields_Forever>
# Process: <09-Penny_Lane>
# Process: <10-Baby_You_re_A_Rich_Man>
# Process: <11-All_You_Need_Is_Love>
# Process: <01-I_Saw_Her_Standing_There>
# Process: <02-Misery>
# Process: <03-Anna_Go_To_Him_>
# Process: <04-Chains>
# Process: <05-Boys>
# Process: <06-Ask_Me_Why>
# Process: <07-Please_Please_Me>
# Process: <08-Love_Me_Do>
# Process: <09-P_S_I_Love_You>
# Process: <10-Baby_It_s_You>
# Process: <11-Do_You_Want_To_Know_A_Secret>
# Process: <12-A_Taste_Of_Honey>
# Process: <13-There_s_A_Place>
# Process: <14-Twist_And_Shout>
# Process: <01-Taxman>
# Process: <02-Eleanor_Rigby>
# Process: <03-I_m_Only_Sleeping>
# Process: <04-Love_You_To>
# Process: <05-Here_There_And_Everywhere>
# Process: <06-Yellow_Submarine>
# Process: <07-She_Said_She_Said>
# Process: <08-Good_Day_Sunshine>
# Process: <09-And_Your_Bird_Can_Sing>
# Process: <10-For_No_One>
# Process: <11-Doctor_Robert>
# Process: <12-I_Want_To_Tell_You>
# Process: <13-Got_To_Get_You_Into_My_Life>
# Process: <14-Tomorrow_Never_Knows>
# Process: <01-Drive_My_Car>
# Process: <02-Norwegian_Wood_This_Bird_Has_Flown_>
# Process: <03-You_Won_t_See_Me>
# Process: <04-Nowhere_Man>
# Process: <05-Think_For_Yourself>
# Process: <06-The_Word>
# Process: <07-Michelle>
# Process: <08-What_Goes_On>
# Process: <09-Girl>
# Process: <10-I_m_Looking_Through_You>
# Process: <11-In_My_Life>
# Process: <12-Wait>
# Process: <13-If_I_Needed_Someone>
# Process: <14-Run_For_Your_Life>
# Process: <01-Sgt_Pepper_s_Lonely_Hearts_Club_Band>
# Process: <02-With_A_Little_Help_From_My_Friends>
# Process: <03-Lucy_In_The_Sky_With_Diamonds>
# Process: <04-Getting_Better>
# Process: <05-Fixing_A_Hole>
# Process: <06-She_s_Leaving_Home>
# Process: <07-Being_For_The_Benefit_Of_Mr_Kite>
# Process: <08-Within_You_Without_You>
# Process: <09-When_I_m_Sixty-Four>
# Process: <10-Lovely_Rita>
# Process: <11-Good_Morning_Good_Morning>
# Process: <12-Sgt_Pepper_s_Lonely_Hearts_Club_Band_Reprise_>
# Process: <13-A_Day_In_The_Life>
# Process: <01-Back_In_The_U_S_S_R_>
# Process: <02-Dear_Prudence>
# Process: <03-Glass_Onion>
# Process: <04-Ob-La-Di_Ob-La-Da>
# Process: <05-Wild_Honey_Pie>
# Process: <06-The_Continuing_Story_Of_Bungalow_Bill>
# Process: <07-While_My_Guitar_Gently_Weeps>
# Process: <08-Happiness_Is_A_Warm_Gun>
# Process: <09-Martha_My_Dear>
# Process: <10-I_m_So_Tired>
# Process: <11-Blackbird>
# Process: <12-Piggies>
# Process: <13-Rocky_Raccoon>
# Process: <14-Don_t_Pass_Me_By>
# Process: <15-Why_Don_t_We_Do_It_In_The_Road>
# Process: <16-I_Will>
# Process: <17-Julia>
# Process: <01-Birthday>
# Process: <02-Yer_Blues>
# Process: <03-Mother_Nature_s_Son>
# Process: <04-Everybody_s_Got_Something_To_Hide_Except_Me_And_My_Monkey>
# Process: <05-Sexy_Sadie>
# Process: <06-Helter_Skelter>
# Process: <07-Long_Long_Long>
# Process: <08-Revolution_1>
# Process: <09-Honey_Pie>
# Process: <10-Savoy_Truffle>
# Process: <11-Cry_Baby_Cry>
# Process: <12-Revolution_9>
# Process: <13-Good_Night>
# Process: <01-It_Won_t_Be_Long>
# Process: <02-All_I_ve_Got_To_Do>
# Process: <03-All_My_Loving>
# Process: <04-Don_t_Bother_Me>
# Process: <05-Little_Child>
# Process: <06-Till_There_Was_You>
# Process: <07-Please_Mister_Postman>
# Process: <08-Roll_Over_Beethoven>
# Process: <09-Hold_Me_Tight>
# Process: <10-You_Really_Got_A_Hold_On_Me>
# Process: <11-I_Wanna_Be_Your_Man>
# Process: <12-Devil_In_Her_Heart>
# Process: <13-Not_A_Second_Time>
# Process: <14-Money_That_s_What_I_Want_>

# %%
print_ds_compute_average_scores('beatles')
# Out:
# 	thirds:        0.210
# 	thirds_inv:    0.202
# 	triads:        0.203
# 	triads_inv:    0.197
# 	tetrads:       0.188
# 	tetrads_inv:   0.184
# 	root:          0.229
# 	mirex:         0.210
# 	majmin:        0.214
# 	majmin_inv:    0.208
# 	sevenths:      0.201
# 	sevenths_inv:  0.196
# 	underseg:      0.380
# 	overseg:       0.895
# 	seg:           0.374
